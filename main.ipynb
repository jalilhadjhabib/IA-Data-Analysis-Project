# %%
# %run Traitement_des_données.ipynb

# %%
# %run SVC_Model_ML_Résolution.ipynb
# Out:
# Scores: [0.73684211 0.71929825 0.69090909 0.66055046 0.77586207 0.66666667
#  0.68468468 0.77310924 0.72566372 0.66055046]
# Mean: 0.7094136740045982
# Standard deviation: 0.04140420152754297
# Scores: [0.9929078  0.9929078  1.         0.9929078  0.98571429 1.
#  0.98571429 1.         0.98571429 1.        ]
# Mean: 0.9935866261398176
# Standard deviation: 0.005931518333574744

# %%
# %run SGD_Model_ML_Résolution.ipynb
# Out:
# Scores: [0.34862385 0.3        0.49253731 0.4962406  0.34482759 0.22988506
#  0.22680412 0.49612403 0.46031746 0.19753086]
# Mean: 0.3592890891059849
# Standard deviation: 0.11390470154628711
# GridSearchCV(cv=10, estimator=SGDClassifier(max_iter=200, random_state=42),
#              param_grid=[{'alpha': [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0,
#                                     1000.0],
#                           'loss': ['hinge', 'log', 'modified_huber',
#                                    'squared_hinge', 'perceptron'],
#                           'penalty': ['l1', 'l2', 'elasticnet']}],
#              return_train_score=True, scoring='f1')
# Scores: [0.36842105 0.27272727 0.46017699 0.45333333 0.33333333 0.4379562
#  0.38926174 0.45945946 0.39694656 0.46391753]
# Mean: 0.4035533482640118
# Standard deviation: 0.060963643096961354

# %%
# %run RL_Model_ML_Résolution.ipynb
# Out:
# Scores: [0.35643564 0.3125     0.34042553 0.375      0.32323232 0.31111111
#  0.34951456 0.37113402 0.32258065 0.31914894]
# Mean: 0.338108277487954
# Standard deviation: 0.022648516813248205
# GridSearchCV(cv=10, estimator=LogisticRegression(),
#              param_grid=[{'C': [100, 10, 1.0, 0.1, 0.01],
#                           'penalty': ['none', 'l1', 'l2', 'elasticnet'],
#                           'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                      'saga']}],
#              return_train_score=True, scoring='f1')
# Scores: [0.35643564 0.3125     0.34042553 0.37113402 0.32323232 0.32967033
#  0.36538462 0.37113402 0.32258065 0.33684211]
# Mean: 0.34293392354280805
# Standard deviation: 0.02055426684823329

# %%
# %run RF_Model_ML_Résolution.ipynb
# Out:
# Scores: [0.97167139 0.98583569 0.9631728  0.98016997 0.98866856 0.97450425
#  0.97733711 0.98583569 0.96590909 0.98295455]
# Mean: 0.9776059103785733
# Standard deviation: 0.008264770638215345
# {'max_features': 2, 'n_estimators': 70}
# 0.9926168283963228
# Scores: [0.97167139 0.98583569 0.9631728  0.98016997 0.98866856 0.97450425
#  0.97733711 0.98583569 0.96590909 0.98295455]
# Mean: 0.9776059103785733
# Standard deviation: 0.008264770638215345

# %%
# %run PERCEPTRON_Model_ML_Résolution.ipynb
# Out:
# Scores: [0.34482759 0.20833333 0.31724138 0.25165563 0.32432432 0.29411765
#  0.22754491 0.30434783 0.38674033 0.38095238]
# Mean: 0.30400853480834866
# Standard deviation: 0.05732202164609077
# Scores: [0.42937853 0.36363636 0.37864078 0.4        0.3373494  0.408
#  0.45945946]
# Mean: 0.3966377897798086
# Standard deviation: 0.03796054842331022
# Saving figure precision_recall_vs_threshold_plot
# Saving figure precision_vs_recall_plot

# %%
# %run MLP_Model_ML_Résolution.ipynb
# Out:
# Scores: [1.        1.        1.        0.9929078 0.9929078 1.        1.
#  1.        1.        1.       ]
# Mean: 0.9985815602836879
# Standard deviation: 0.0028368794326241176
# GridSearchCV(cv=3, estimator=MLPClassifier(max_iter=300, random_state=1),
#              n_jobs=-1,
#              param_grid={'activation': ['tanh', 'relu', 'logistic'],
#                          'alpha': [0.0001, 0.05],
#                          'hidden_layer_sizes': [(50, 50, 50), (50, 100, 50),
#                                                 (100,)],
#                          'learning_rate': ['constant', 'adaptive'],
#                          'solver': ['sgd', 'adam']})
# Best Score:
# 0.9696712018140589
# Best Estimator:
# MLPClassifier(activation='tanh', alpha=0.05, max_iter=300, random_state=1)
# Best Params:
# {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'adam'}
# ...

# %%
# %run COURBE_ROC_ALL_MODELS.ipynb

# %%
# %run Pertinant_Criterias_and_Optimization_of_MLP.ipynb
# Out:
# MLPClassifier(activation='tanh', alpha=0.05, max_iter=300, random_state=1)
